# %% [markdown]
# #Wykresy

# %% [markdown]
# #Wykres1

# %%
import matplotlib.pyplot as plt;
x = [0,1,2,3,4];
y = [2,4,6,8,10];
plt.plot(x,y);
plt.show();

# %% [markdown]
# **Wykres 2**

# %%
import pandas as pd;
import matplotlib.pyplot as plt;

df = pd.read_csv('dane_sprzedaz.csv',sep=';');
df.plot();
plt.xlabel("Miesiąc sprzedaży");
plt.ylabel("Zysk");

plt.show();
